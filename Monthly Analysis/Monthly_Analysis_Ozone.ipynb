# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import math

# %%
data_b_NO2=pd.read_excel("/Users/roshanchandraayyadevara/Documents/Dataset_Dessertation/Month/Mon_O3_Data.xlsx",sheet_name='Birmingham')
data_l_NO2=pd.read_excel("/Users/roshanchandraayyadevara/Documents/Dataset_Dessertation/Month/Mon_O3_Data.xlsx",sheet_name='London')
data_lp_NO2=pd.read_excel("/Users/roshanchandraayyadevara/Documents/Dataset_Dessertation/Month/Mon_O3_Data.xlsx",sheet_name='Liverpool')

# %%
data_b_NO2.head()
# Out:
#            Site Name        City  Year  Jan  Feb  Mar  Apr  May  Jun  Jul  \
# 0  Birmingham Centre  Birmingham  2000   30   47   45   43   47   43   36
# 1    Birmingham East  Birmingham  2000   27   40   38   43   47   41   34
# 2  Birmingham Centre  Birmingham  2001   24   30   37   53   45   52   46
# 3    Birmingham East  Birmingham  2001   23   25   39   54   50   53   49
# 4  Birmingham Centre  Birmingham  2002   32   51   41   52   56   52   39
#
#    Aug  Sep  Oct  Nov  Dec  Units
# 0   35   28   32   29   28  ugm-3
# 1   33   30   31   30   27  ugm-3
# 2   38   32   33   22   22  ugm-3
# 3   37   31   34   19   20  ugm-3
# 4   36   32   25   23   21  ugm-3

# %%
df_b_NO2 = data_b_NO2.groupby('Year').agg({
    'Jan': 'mean',
    'Feb': 'mean',
    'Mar': 'mean',
    'Apr': 'mean',
    'May': 'mean',
    'Jun': 'mean',
    'Jul': 'mean',
    'Aug': 'mean',
    'Sep': 'mean',
    'Oct': 'mean',
    'Nov': 'mean',
    'Dec': 'mean'
}).reset_index()

# %%
df_l_NO2 = data_l_NO2.groupby('Year').agg({
    'Jan': 'mean',
    'Feb': 'mean',
    'Mar': 'mean',
    'Apr': 'mean',
    'May': 'mean',
    'Jun': 'mean',
    'Jul': 'mean',
    'Aug': 'mean',
    'Sep': 'mean',
    'Oct': 'mean',
    'Nov': 'mean',
    'Dec': 'mean'
}).reset_index()

# %%
df_lp_NO2 = data_lp_NO2.groupby('Year').agg({
    'Jan': 'mean',
    'Feb': 'mean',
    'Mar': 'mean',
    'Apr': 'mean',
    'May': 'mean',
    'Jun': 'mean',
    'Jul': 'mean',
    'Aug': 'mean',
    'Sep': 'mean',
    'Oct': 'mean',
    'Nov': 'mean',
    'Dec': 'mean'
}).reset_index()

# %%
df_b_NO2.head()
# Out:
#    Year   Jan   Feb        Mar        Apr        May   Jun        Jul   Aug  \
# 0  2000  28.5  43.5  41.500000  43.000000  47.000000  42.0  35.000000  34.0
# 1  2001  23.5  27.5  38.000000  53.500000  47.500000  52.5  47.500000  37.5
# 2  2002  31.0  49.5  42.000000  53.000000  57.500000  52.5  39.500000  34.5
# 3  2003  33.5  26.5  44.500000  57.500000  67.500000  63.0  52.000000  50.0
# 4  2004  36.0  34.0  43.666667  43.666667  44.666667  48.0  42.333333  47.0
#
#          Sep   Oct   Nov   Dec
# 0  29.000000  31.5  29.5  27.5
# 1  31.500000  33.5  20.5  21.0
# 2  34.500000  27.0  24.0  22.5
# 3  34.000000  28.0  24.5  22.5
# 4  43.333333  34.0  27.0  26.0

# %% [markdown]
# # Birmingham's NO2

# %%
import matplotlib.pyplot as plt

# Assuming 'Year' column is numeric, if it's not, you can convert it to a string using: df_b_NO2['Year'] = df_b_NO2['Year'].astype(str)

# Extract the monthly mean values for each month
data = [
    df_b_NO2['Jan'],
    df_b_NO2['Feb'],
    df_b_NO2['Mar'],
    df_b_NO2['Apr'],
    df_b_NO2['May'],
    df_b_NO2['Jun'],
    df_b_NO2['Jul'],
    df_b_NO2['Aug'],
    df_b_NO2['Sep'],
    df_b_NO2['Oct'],
    df_b_NO2['Nov'],
    df_b_NO2['Dec']
]

# Set up the figure and axis
plt.figure(figsize=(10, 6))
ax = plt.gca()

# Create the box plot with colors
box_plot = ax.boxplot(data, labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], patch_artist=True)

# Customizing the colors of boxes and median lines
box_colors = ['lightblue', 'lightgreen', 'lightcoral', 'tan', 'pink', 'lightyellow', 'lightgrey', 'lavender', 'lightskyblue', 'lightgreen', 'lightcoral', 'tan']
median_color = 'blue'

for patch, color in zip(box_plot['boxes'], box_colors):
    patch.set_facecolor(color)
    
for median in box_plot['medians']:
    median.set(color=median_color, linewidth=2)

# Adding labels, title, and legend
ax.set_xlabel('Month')
ax.set_ylabel('Monthly Mean')
ax.set_title('Monthly Mean O3 of Birmingham')

# Show the plot
plt.grid()
plt.show()

# %%
import pandas as pd

data_without_column = df_b_NO2.drop(columns=['Year'])

# Calculate the summary statistics for the remaining columns
summary_stats = data_without_column.describe()
print(summary_stats)
# Out:
#              Jan        Feb        Mar        Apr        May        Jun  \
# count  23.000000  23.000000  23.000000  23.000000  23.000000  23.000000
# mean   32.246377  37.500000  45.949275  53.793478  56.003623  49.561594
# std     7.006647  10.473512   6.836554   5.548903   6.236525   6.177418
# min    20.500000  24.500000  31.666667  43.000000  44.666667  41.333333
# 25%    26.833333  30.250000  42.000000  50.250000  53.583333  44.583333
# 50%    33.500000  34.333333  45.333333  53.750000  55.333333  48.000000
# 75%    37.000000  43.500000  47.500000  57.416667  60.541667  53.500000
# max    44.333333  59.666667  62.000000  67.333333  67.500000  63.000000
#
#              Jul        Aug        Sep        Oct        Nov        Dec
# count  23.000000  23.000000  23.000000  23.000000  23.000000  23.000000
# mean   44.271739  39.681159  35.068841  31.199275  27.347826  28.829710
# std     7.067952   5.736185   4.633040   6.066797   5.803585   8.117916
# min    35.000000  29.000000  29.000000  19.500000  17.666667  13.000000
# 25%    39.500000  35.500000  32.000000  27.500000  23.666667  22.500000
# 50%    43.333333  38.500000  34.000000  31.666667  25.666667  30.333333
# 75%    48.250000  43.166667  37.833333  34.500000  30.750000  33.750000
# max    62.500000  52.000000  47.000000  46.333333  39.666667  45.666667

# %%
import pandas as pd

data_without_column = df_b_NO2.drop(columns=['Year'])

# Calculate the summary statistics for the remaining columns
summary_stats = data_without_column.describe()

# Accessing specific description parameters using indexing
mean_value = summary_stats.loc['mean']  # Mean value for each column
std_deviation = summary_stats.loc['std']  # Standard deviation for each column
min_value = summary_stats.loc['min']  # Minimum value for each column
max_value = summary_stats.loc['max']  # Maximum value for each column

# Accessing specific description parameters using attribute access
mean_value = summary_stats.mean()  # Mean value for each column
std_deviation = summary_stats.std()  # Standard deviation for each column
min_value = summary_stats.min()  # Minimum value for each column
max_value = summary_stats.max()  # Maximum value for each column
variance= summary_stats.var()
print("Mean:")
print(mean_value)

print("\nStandard Deviation:")
print(std_deviation)

print("\nMinimum Value:")
print(min_value)

print("\nMaximum Value:")
print(max_value)

print("\nVariance:")
print(variance)
# Out:
# Mean:
# Jan    28.052461
# Feb    32.902939
# Mar    38.035729
# Apr    44.261548
# May    45.858143
# Jun    41.144460
# Jul    37.865378
# Aug    33.323001
# Sep    30.316902
# Oct    27.470759
# Nov    24.196010
# Dec    25.649703
# dtype: float64
#
# Standard Deviation:
# Jan    11.460301
# Feb    14.786909
# Mar    17.052356
# Apr    20.264072
# May    20.805739
# Jun    18.173558
# Jul    16.758743
# Aug    14.162223
# Sep    12.471301
# Oct    11.822289
# Nov     9.834466
# Dec    11.848222
# dtype: float64
#
# Minimum Value:
# Jan     7.006647
# Feb    10.473512
# Mar     6.836554
# Apr     5.548903
# May     6.236525
# Jun     6.177418
# Jul     7.067952
# Aug     5.736185
# Sep     4.633040
# Oct     6.066797
# Nov     5.803585
# Dec     8.117916
# dtype: float64
#
# Maximum Value:
# Jan    44.333333
# Feb    59.666667
# Mar    62.000000
# Apr    67.333333
# May    67.500000
# Jun    63.000000
# Jul    62.500000
# Aug    52.000000
# Sep    47.000000
# Oct    46.333333
# Nov    39.666667
# Dec    45.666667
# dtype: float64
#
# Variance:
# Jan    131.338493
# Feb    218.652672
# Mar    290.782860
# Apr    410.632604
# May    432.878765
# Jun    330.278224
# Jul    280.855467
# Aug    200.568566
# Sep    155.533359
# Oct    139.766508
# Nov     96.716721
# Dec    140.380370
# dtype: float64

# %%
sorted_mean = mean_value.sort_values(ascending=False)

# Print the sorted mean values
print("Sorted Mean Values (Highest to Lowest):")
print(sorted_mean)
# Out:
# Sorted Mean Values (Highest to Lowest):
# May    48.867320
# Apr    47.811299
# Jun    43.995998
# Mar    41.433743
# Jul    40.005888
# Feb    37.690567
# Aug    37.010991
# Sep    34.389124
# Jan    33.805590
# Dec    31.652560
# Oct    31.481310
# Nov    30.880025
# dtype: float64

# %% [markdown]
# # London's NO2

# %%
import matplotlib.pyplot as plt

# Assuming 'Year' column is numeric, if it's not, you can convert it to a string using: df_b_NO2['Year'] = df_b_NO2['Year'].astype(str)

# Extract the monthly mean values for each month
data = [
    df_l_NO2['Jan'],
    df_l_NO2['Feb'],
    df_l_NO2['Mar'],
    df_l_NO2['Apr'],
    df_l_NO2['May'],
    df_l_NO2['Jun'],
    df_l_NO2['Jul'],
    df_l_NO2['Aug'],
    df_l_NO2['Sep'],
    df_l_NO2['Oct'],
    df_l_NO2['Nov'],
    df_l_NO2['Dec']
]

# Set up the figure and axis
plt.figure(figsize=(10, 6))
ax = plt.gca()

# Create the box plot with colors
box_plot = ax.boxplot(data, labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], patch_artist=True)

# Customizing the colors of boxes and median lines
box_colors = ['lightblue', 'lightgreen', 'lightcoral', 'tan', 'pink', 'lightyellow', 'lightgrey', 'lavender', 'lightskyblue', 'lightgreen', 'lightcoral', 'tan']
median_color = 'blue'

for patch, color in zip(box_plot['boxes'], box_colors):
    patch.set_facecolor(color)
    
for median in box_plot['medians']:
    median.set(color=median_color, linewidth=2)

# Adding labels, title, and legend
ax.set_xlabel('Month')
ax.set_ylabel('Monthly Mean')
ax.set_title('Monthly Mean O3 of London')

# Show the plot
plt.grid()
plt.show()

# %%
import pandas as pd

data_without_column = df_l_NO2.drop(columns=['Year'])

# Calculate the summary statistics for the remaining columns
summary_stats = data_without_column.describe()

# Accessing specific description parameters using indexing
mean_value = summary_stats.loc['mean']  # Mean value for each column
std_deviation = summary_stats.loc['std']  # Standard deviation for each column
min_value = summary_stats.loc['min']  # Minimum value for each column
max_value = summary_stats.loc['max']  # Maximum value for each column

# Accessing specific description parameters using attribute access
mean_value = summary_stats.mean()  # Mean value for each column
std_deviation = summary_stats.std()  # Standard deviation for each column
min_value = summary_stats.min()  # Minimum value for each column
max_value = summary_stats.max()  # Maximum value for each column
variance= summary_stats.var()
print("Mean:")
print(mean_value)

print("\nStandard Deviation:")
print(std_deviation)

print("\nMinimum Value:")
print(min_value)

print("\nMaximum Value:")
print(max_value)

print("\nVariance:")
print(variance)
# Out:
# Mean:
# Jan    22.481359
# Feb    27.286237
# Mar    32.384395
# Apr    39.643476
# May    42.009465
# Jun    37.819895
# Jul    36.122532
# Aug    31.947608
# Sep    26.388772
# Oct    21.875247
# Nov    19.791174
# Dec    21.769799
# dtype: float64
#
# Standard Deviation:
# Jan     8.741896
# Feb    11.995762
# Mar    13.889046
# Apr    17.506473
# May    19.193089
# Jun    16.361103
# Jul    15.845683
# Aug    13.237124
# Sep    10.670175
# Oct     8.878982
# Nov     7.935137
# Dec     9.685135
# dtype: float64
#
# Minimum Value:
# Jan    5.389305
# Feb    8.375124
# Mar    6.780294
# Apr    5.894612
# May    4.881917
# Jun    5.536038
# Jul    7.082136
# Aug    7.274892
# Sep    4.922047
# Oct    4.832183
# Nov    5.481891
# Dec    6.681778
# dtype: float64
#
# Maximum Value:
# Jan    33.200000
# Feb    49.285714
# Mar    52.142857
# Apr    62.000000
# May    65.571429
# Jun    55.428571
# Jul    60.600000
# Aug    53.000000
# Sep    41.000000
# Oct    34.000000
# Nov    33.000000
# Dec    38.250000
# dtype: float64
#
# Variance:
# Jan     76.420749
# Feb    143.898298
# Mar    192.905598
# Apr    306.476593
# May    368.374657
# Jun    267.685704
# Jul    251.085679
# Aug    175.221444
# Sep    113.852631
# Oct     78.836328
# Nov     62.966398
# Dec     93.801848
# dtype: float64

# %%
sorted_mean = mean_value.sort_values(ascending=False)

# Print the sorted mean values
print("Sorted Mean Values (Highest to Lowest):")
print(sorted_mean)
# Out:
# Sorted Mean Values (Highest to Lowest):
# May    42.009465
# Apr    39.643476
# Jun    37.819895
# Jul    36.122532
# Mar    32.384395
# Aug    31.947608
# Feb    27.286237
# Sep    26.388772
# Jan    22.481359
# Oct    21.875247
# Dec    21.769799
# Nov    19.791174
# dtype: float64

# %% [markdown]
# # Liverpool's NO2

# %%
import matplotlib.pyplot as plt

# Assuming 'Year' column is numeric, if it's not, you can convert it to a string using: df_b_NO2['Year'] = df_b_NO2['Year'].astype(str)

# Extract the monthly mean values for each month
data = [
    df_lp_NO2['Jan'],
    df_lp_NO2['Feb'],
    df_lp_NO2['Mar'],
    df_lp_NO2['Apr'],
    df_lp_NO2['May'],
    df_lp_NO2['Jun'],
    df_lp_NO2['Jul'],
    df_lp_NO2['Aug'],
    df_lp_NO2['Sep'],
    df_lp_NO2['Oct'],
    df_lp_NO2['Nov'],
    df_lp_NO2['Dec']
]

# Set up the figure and axis
plt.figure(figsize=(10, 6))
ax = plt.gca()

# Create the box plot with colors
box_plot = ax.boxplot(data, labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], patch_artist=True)

# Customizing the colors of boxes and median lines
box_colors = ['lightblue', 'lightgreen', 'lightcoral', 'tan', 'pink', 'lightyellow', 'lightgrey', 'lavender', 'lightskyblue', 'lightgreen', 'lightcoral', 'tan']
median_color = 'blue'

for patch, color in zip(box_plot['boxes'], box_colors):
    patch.set_facecolor(color)
    
for median in box_plot['medians']:
    median.set(color=median_color, linewidth=2)

# Adding labels, title, and legend
ax.set_xlabel('Month')
ax.set_ylabel('Monthly Mean')
ax.set_title('Monthly Mean O3 in Liverpool')

# Show the plot
plt.grid()
plt.show()

# %%
import pandas as pd

data_without_column = df_lp_NO2.drop(columns=['Year'])

# Calculate the summary statistics for the remaining columns
summary_stats = data_without_column.describe()

# Accessing specific description parameters using indexing
mean_value = summary_stats.loc['mean']  # Mean value for each column
std_deviation = summary_stats.loc['std']  # Standard deviation for each column
min_value = summary_stats.loc['min']  # Minimum value for each column
max_value = summary_stats.loc['max']  # Maximum value for each column

# Accessing specific description parameters using attribute access
mean_value = summary_stats.mean()  # Mean value for each column
std_deviation = summary_stats.std()  # Standard deviation for each column
min_value = summary_stats.min()  # Minimum value for each column
max_value = summary_stats.max()  # Maximum value for each column
variance= summary_stats.var()
print("Mean:")
print(mean_value)

print("\nStandard Deviation:")
print(std_deviation)

print("\nMinimum Value:")
print(min_value)

print("\nMaximum Value:")
print(max_value)

print("\nVariance:")
print(variance)
# Out:
# Mean:
# Jan    33.805590
# Feb    37.690567
# Mar    41.433743
# Apr    47.811299
# May    48.867320
# Jun    43.995998
# Jul    40.005888
# Aug    37.010991
# Sep    34.389124
# Oct    31.481310
# Nov    30.880025
# Dec    31.652560
# dtype: float64
#
# Standard Deviation:
# Jan    15.447933
# Feb    17.961294
# Mar    19.536491
# Apr    22.050174
# May    22.649066
# Jun    19.837095
# Jul    18.220334
# Aug    15.929432
# Sep    14.483907
# Oct    12.925650
# Nov    12.421162
# Dec    14.642713
# dtype: float64
#
# Minimum Value:
# Jan    11.205589
# Feb     9.741927
# Mar     8.861249
# Apr     7.012130
# May     6.329865
# Jun     4.859285
# Jul     6.003622
# Aug     6.435757
# Sep     5.765167
# Oct     7.285266
# Nov     5.822812
# Dec     9.829173
# dtype: float64
#
# Maximum Value:
# Jan    55.0
# Feb    67.0
# Mar    68.0
# Apr    69.0
# May    72.0
# Jun    64.0
# Jul    66.0
# Aug    56.0
# Sep    50.0
# Oct    50.0
# Nov    47.0
# Dec    57.0
# dtype: float64
#
# Variance:
# Jan    238.638635
# Feb    322.608070
# Mar    381.674466
# Apr    486.210162
# May    512.980198
# Jun    393.510356
# Jul    331.980574
# Aug    253.746818
# Sep    209.783569
# Oct    167.072426
# Nov    154.285260
# Dec    214.409056
# dtype: float64

# %%
sorted_mean = mean_value.sort_values(ascending=False)

# Print the sorted mean values
print("Sorted Mean Values (Highest to Lowest):")
print(sorted_mean)
# Out:
# Sorted Mean Values (Highest to Lowest):
# May    42.009465
# Apr    39.643476
# Jun    37.819895
# Jul    36.122532
# Mar    32.384395
# Aug    31.947608
# Feb    27.286237
# Sep    26.388772
# Jan    22.481359
# Oct    21.875247
# Dec    21.769799
# Nov    19.791174
# dtype: float64
